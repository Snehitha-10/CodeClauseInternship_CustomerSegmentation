# %% [markdown]
# # CUSTOMER SEGMENTATION

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## READING THE DATASET

# %%
df = pd.read_csv('shopping_trends.csv')
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.drop(["Customer ID","Location","Color",'Season','Payment Method','Shipping Type','Preferred Payment Method'],axis=1,inplace=True)

# %%
df.drop(df.index[300:],inplace =True)

# %%
df.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD) Size  \
# 0   55   Male         Blouse  Clothing                     53    L
# 1   19   Male        Sweater  Clothing                     64    L
# 2   50   Male          Jeans  Clothing                     73    S
# 3   21   Male        Sandals  Footwear                     90    M
# 4   45   Male         Blouse  Clothing                     49    M
#
#    Review Rating Subscription Status Discount Applied Promo Code Used  \
# 0            3.1                 Yes              Yes             Yes
# 1            3.1                 Yes              Yes             Yes
# 2            3.1                 Yes              Yes             Yes
# 3            3.5                 Yes              Yes             Yes
# 4            2.7                 Yes              Yes             Yes
#
#    Previous Purchases Frequency of Purchases
# 0                  14            Fortnightly
# 1                   2            Fortnightly
# ...

# %%
df.shape
# Out:
# (300, 12)

# %% [markdown]
# ## PREPROCESSING

# %%
df['Category'] = LabelEncoder().fit_transform(df['Category'])
df.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD) Size  \
# 0   55   Male         Blouse         1                     53    L
# 1   19   Male        Sweater         1                     64    L
# 2   50   Male          Jeans         1                     73    S
# 3   21   Male        Sandals         2                     90    M
# 4   45   Male         Blouse         1                     49    M
#
#    Review Rating Subscription Status Discount Applied Promo Code Used  \
# 0            3.1                 Yes              Yes             Yes
# 1            3.1                 Yes              Yes             Yes
# 2            3.1                 Yes              Yes             Yes
# 3            3.5                 Yes              Yes             Yes
# 4            2.7                 Yes              Yes             Yes
#
#    Previous Purchases Frequency of Purchases
# 0                  14            Fortnightly
# 1                   2            Fortnightly
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 299
# Data columns (total 12 columns):
# Age                       300 non-null int64
# Gender                    300 non-null object
# Item Purchased            300 non-null object
# Category                  300 non-null int64
# Purchase Amount (USD)     300 non-null int64
# Size                      300 non-null object
# Review Rating             300 non-null float64
# Subscription Status       300 non-null object
# Discount Applied          300 non-null object
# Promo Code Used           300 non-null object
# Previous Purchases        300 non-null int64
# Frequency of Purchases    300 non-null object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 30.5+ KB
# None

# %%
df.describe()
# Out:
#              Age    Category  Purchase Amount (USD)  Review Rating  \
# count  300.00000  300.000000             300.000000     300.000000
# mean    44.27000    1.023333              59.250000       3.778000
# std     15.33256    0.948219              23.924509       0.708842
# min     18.00000    0.000000              20.000000       2.500000
# 25%     30.75000    0.000000              38.000000       3.100000
# 50%     45.50000    1.000000              57.500000       3.800000
# 75%     57.00000    1.000000              81.000000       4.400000
# max     70.00000    3.000000             100.000000       5.000000
#
#        Previous Purchases
# count          300.000000
# mean            26.273333
# std             14.188363
# min              1.000000
# 25%             14.000000
# 50%             26.500000
# 75%             38.250000
# max             50.000000

# %%
df.dtypes
# Out:
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                    int64
# Purchase Amount (USD)       int64
# Size                       object
# Review Rating             float64
# Subscription Status        object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Frequency of Purchases     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Size                      0
# Review Rating             0
# Subscription Status       0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# # DATA VISUVALIZING

# %%
plt.figure(1,figsize=(18,4))
n=0
for x in ['Age', 'Purchase Amount (USD)', 'Previous Purchases','Category']:
    n+=1
    plt.subplot(1,4,n)
    plt.subplots_adjust(hspace =0.5 , wspace =0.5)
    sns.distplot(df[x],bins=20)
    plt.title('Distplot of {}'.format(x))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(1,figsize=(18,5))
n=0
for x in ['Age', 'Purchase Amount (USD)', 'Review Rating','Category']:
    n+=1
    plt.subplot(1,4,n)
    sns.set(style='whitegrid')
    plt.subplots_adjust(hspace =0.5 , wspace =0.5)
    sns.violinplot(x=x,y='Gender',data=df)
    plt.title('Voilin plot')
plt.show()

# %%
age1=df.Age[(df.Age >= 18) & (df.Age <= 35)]
age2=df.Age[(df.Age >= 36) & (df.Age <= 55)]
age3=df.Age[(df.Age >= 56) ]

agex = ["Youth" ,'Midlle Age','Old Age']
agey = [len(age1.values),len(age2.values),len(age3.values)]

plt.figure(figsize=(8,6))
sns.barplot(x=agex,y=agey)
plt.title("Number of Customers and Ages")
plt.xlabel('Age')
plt.ylabel("No.of Custumers")
plt.show()

# %%
pa1=df["Purchase Amount (USD)"][(df["Purchase Amount (USD)"] >= 20) & (df["Purchase Amount (USD)"] <= 35)]
pa2=df["Purchase Amount (USD)"][(df["Purchase Amount (USD)"] >= 36) & (df["Purchase Amount (USD)"] <= 50)]
pa3=df["Purchase Amount (USD)"][(df["Purchase Amount (USD)"] >= 51) & (df["Purchase Amount (USD)"] <= 65)]
pa4=df["Purchase Amount (USD)"][(df["Purchase Amount (USD)"] >= 66) & (df["Purchase Amount (USD)"] <= 80)]
pa5=df["Purchase Amount (USD)"][(df["Purchase Amount (USD)"] >= 81) ]
pax = ["20-35" ,'36-50','51-65','66-80','>80']
pay = [len(pa1.values),len(pa2.values),len(pa3.values),len(pa4.values),len(pa5.values)]

plt.figure(figsize=(8,6))
sns.barplot(x=pax,y=pay)
plt.title("Number of Customers and Purchase Amounts")
plt.xlabel('Purchase Amounts')
plt.ylabel("No.of Custumers")
plt.show()

# %%
pp1=df["Previous Purchases"][(df["Previous Purchases"] >= 1) & (df["Previous Purchases"] <= 10)]
pp2=df["Previous Purchases"][(df["Previous Purchases"] >= 11) & (df["Previous Purchases"] <= 20)]
pp3=df["Previous Purchases"][(df["Previous Purchases"] >= 21) & (df["Previous Purchases"] <= 30)]
pp4=df["Previous Purchases"][(df["Previous Purchases"] >= 31) & (df["Previous Purchases"] <= 40)]
pp5=df["Previous Purchases"][(df["Previous Purchases"] >= 41) ]
ppx = ["1-10" ,'11-20','21-30','31-40','>41']
ppy = [len(pp1.values),len(pp2.values),len(pp3.values),len(pp4.values),len(pp5.values)]

plt.figure(figsize=(8,6))
sns.barplot(x=ppx,y=ppy)
plt.title("Number of Customers and Previous Purchases")
plt.xlabel("Previous Purchases")
plt.ylabel("No.of Custumers")
plt.show()

# %%
plt.figure(figsize=(10,7))
counts = df['Category'].value_counts()
sns.barplot(x=counts.index, y=counts)
plt.title('Categorizing of items ')
plt.xlabel('Category')
plt.ylabel('Count')
# plt.yticks(rotation=90);
# Out:
# Text(0,0.5,'Count')

# %%
X1=df.loc[:, ["Age", "Purchase Amount (USD)"]].values
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
label = kmeans.fit_predict(X1)
print(label)
# Out:
# [2 1 3 4 2 0 3 0 4 2 2 1 3 2 2 3 0 2 2 3 1 1 2 4 0 0 0 2 3 1 2 4 1 2 4 2 1
#  0 0 3 3 2 4 1 1 2 2 2 1 2 2 2 0 0 4 0 1 1 2 3 2 3 0 4 3 2 4 2 2 3 0 1 0 3
#  1 3 2 1 3 4 1 3 0 0 2 3 0 2 1 3 1 4 3 1 3 4 1 4 1 0 3 4 3 3 2 3 2 1 3 3 2
#  1 1 1 3 3 3 2 2 4 3 1 0 3 4 2 0 4 0 1 2 0 1 3 4 4 4 2 2 3 2 2 1 1 0 4 2 3
#  4 4 4 1 4 2 4 3 0 1 1 2 0 2 3 3 3 1 2 0 4 0 2 0 3 0 0 3 3 0 2 2 3 1 4 2 0
#  2 1 4 2 4 3 3 2 4 3 2 4 3 2 3 1 2 2 2 4 3 1 3 2 3 0 3 3 4 1 3 1 1 0 4 1 1
#  4 0 3 0 1 3 4 2 3 0 2 4 0 4 1 3 2 2 2 4 3 4 2 2 4 1 4 2 0 1 0 3 2 0 2 1 3
#  1 1 4 0 0 4 1 3 2 2 2 1 3 2 2 2 3 0 0 3 1 1 1 4 0 2 0 1 2 1 3 2 2 3 2 2 2
#  1 2 2 4]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[29.68085106 32.08510638]
#  [31.01724138 60.74137931]
#  [57.31707317 38.43902439]
#  [58.27272727 81.62121212]
#  [32.78723404 89.46808511]]

# %%
plt.scatter (X1[:,0], X1[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], color="black")
plt.title('Clusters of Customers')
plt.xlabel('Age')
plt.ylabel('Purchase Amount (USD)')
plt.show()

# %%
X2=df.loc[:, ["Age", "Previous Purchases"]].values
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(X2)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
label = kmeans.fit_predict(X2)
print(label)
# Out:
# [4 2 0 1 0 0 3 2 2 4 0 2 3 3 3 4 1 3 0 3 1 2 3 1 2 2 2 4 3 2 4 1 1 3 1 3 1
#  2 1 4 3 3 2 2 1 0 3 3 1 3 3 4 0 1 0 1 1 2 3 4 0 0 1 1 4 3 2 1 0 4 1 1 2 3
#  4 4 0 1 3 1 2 3 2 1 3 4 1 3 1 0 1 0 4 1 0 1 1 1 2 1 3 1 3 0 4 4 3 1 3 3 0
#  2 1 0 4 3 4 0 0 1 3 2 1 3 1 3 1 2 2 1 0 1 1 0 0 0 2 3 3 0 3 3 1 2 2 1 0 3
#  1 2 2 2 1 4 0 4 1 2 1 3 1 3 0 4 4 2 0 2 2 2 3 2 3 1 1 4 0 1 4 4 4 2 2 0 1
#  0 1 2 4 2 3 3 0 1 0 3 1 3 3 3 1 4 3 4 1 4 2 4 4 3 4 3 4 2 1 0 0 2 2 2 1 2
#  0 1 4 2 2 0 2 3 3 2 3 2 2 0 1 3 4 3 0 1 3 2 3 3 2 2 0 0 2 1 1 0 4 0 0 2 4
#  2 2 2 2 1 2 2 0 3 4 4 2 3 3 3 0 0 2 1 0 1 0 0 2 2 4 2 2 0 1 0 3 3 0 3 4 0
#  2 4 4 1]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[49.8        23.34545455]
#  [31.38235294 39.94117647]
#  [27.88235294 12.55882353]
#  [59.07692308 39.18461538]
#  [60.72727273 10.93181818]]

# %%
plt.scatter (X2[:,0],X2[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], color="black")
plt.title('Clusters of Customers')
plt.xlabel('Age')
plt.ylabel('Previous Purchases')
plt.show()

# %%
X3=df.loc[:, ["Age", "Previous Purchases","Purchase Amount (USD)"]].values

wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(X2)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11), wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
label = kmeans.fit_predict(X3)
print(label)
# Out:
# [0 1 1 2 0 0 2 3 1 0 0 1 2 0 0 1 3 0 0 2 3 1 0 2 3 3 3 1 2 3 0 2 2 0 2 0 2
#  3 3 0 2 0 1 1 3 0 0 0 3 0 0 1 0 3 2 3 2 1 0 1 0 1 3 2 1 0 1 0 0 1 3 3 3 2
#  1 2 0 3 2 2 1 2 3 3 0 1 3 0 3 1 3 1 1 2 2 2 2 2 1 3 2 2 2 2 0 1 0 2 2 2 0
#  1 1 3 1 2 1 0 0 2 2 1 3 2 2 0 0 1 3 2 3 3 3 1 2 1 1 0 0 2 0 0 3 3 3 2 0 0
#  2 1 1 3 2 0 1 1 3 1 2 0 3 0 2 1 1 1 0 3 1 3 0 3 2 3 3 1 2 3 0 0 1 1 1 0 3
#  0 3 1 1 1 2 2 0 2 1 0 2 2 0 2 3 0 0 0 2 0 3 1 0 2 0 2 1 1 3 0 1 3 3 1 3 1
#  1 3 1 3 1 2 1 0 2 3 0 1 3 2 2 2 0 0 0 2 2 1 0 0 1 1 2 0 3 3 3 1 0 0 0 3 1
#  3 1 1 3 3 1 3 2 0 0 0 3 2 0 0 0 1 3 3 2 2 1 1 1 3 0 3 3 0 3 2 0 0 2 0 0 0
#  1 0 0 1]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[57.14942529 28.33333333 38.10344828]
#  [40.78666667 12.62666667 78.18666667]
#  [46.82608696 38.5942029  83.86956522]
#  [29.26086957 26.1884058  40.71014493]]

# %%
plt.scatter (X3[:,0],X3[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], color="black")
plt.title('Clusters of Customers')
plt.xlabel('Age')
plt.ylabel('Previous Purchases')
plt.show()

# %%
clusters = kmeans.fit_predict(X3)
df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = (20,10))
ax=fig.add_subplot(111, projection="3d")
ax.scatter (df.Age[df.label == 0], df["Purchase Amount (USD)"][df.label == 0],df["Previous Purchases"][df.label == 0], c= 'blue',s = 60)
ax.scatter (df.Age[df.label == 1], df["Purchase Amount (USD)"][df.label == 1],df["Previous Purchases"][df.label == 1], c= 'red',s = 60)
ax.scatter (df.Age[df.label == 2], df["Purchase Amount (USD)"][df.label == 2],df["Previous Purchases"][df.label == 2], c= 'green',s = 60)
ax.scatter (df.Age[df.label == 3], df["Purchase Amount (USD)"][df.label == 3],df["Previous Purchases"][df.label == 3], c= 'orange',s = 60)
# ax.scatter (df.Age[df.label == 4], df["Purchase Amount (USD)"][df.label == 4],df["Previous Purchases"][df.label == 4], c= 'purple',s = 60)


ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Purchase Amount (USD)")
ax.set_zlabel("Previous Purchases")
plt.show()
